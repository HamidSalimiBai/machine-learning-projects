# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
data = pd.read_csv('diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df = pd.DataFrame(data.drop('Pregnancies', axis= 1))
df
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2        183             64              0        0  23.3
# 3         89             66             23       94  28.1
# 4        137             40             35      168  43.1
# ..       ...            ...            ...      ...   ...
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 766      126             60              0        0  30.1
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize = (8, 4))
plt.scatter(x = 'Glucose', y = 'Outcome', data = df)
plt.xlabel('Glucose')
plt.ylabel('Outcome')
plt.grid()

# %%
plt.figure(figsize = (8, 4))
plt.scatter(x = 'BloodPressure', y = 'Outcome', data = df)
plt.xlabel('BloodPressure')
plt.ylabel('Outcome')
plt.grid()

# %%
plt.figure(figsize = (8, 4))
plt.scatter(x = 'SkinThickness', y = 'Outcome', data = df)
plt.xlabel('SkinThickness')
plt.ylabel('Outcome')
plt.grid()

# %%
plt.figure(figsize = (8, 4))
plt.scatter(x = 'Insulin', y = 'Outcome', data = df)
plt.xlabel('Insulin')
plt.ylabel('Outcome')
plt.grid()

# %%
plt.figure(figsize = (8, 4))
plt.scatter(x = 'BMI', y = 'Outcome', data = df)
plt.xlabel('BMI')
plt.ylabel('Outcome')
plt.grid()

# %%
plt.figure(figsize = (8, 4))
plt.scatter(x = 'DiabetesPedigreeFunction', y = 'Outcome', data = df)
plt.xlabel('DiabetesPedigreeFunction')
plt.ylabel('Outcome')
plt.grid()

# %%
plt.figure(figsize = (8, 4))
plt.scatter(x = 'Age', y = 'Outcome', data = df)
plt.xlabel('Age')
plt.ylabel('Outcome')
plt.grid()

# %%
df.columns
# Out:
# Index(['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
a = df['Glucose'].value_counts().max()
b = df['Glucose'].value_counts().min()
print(a)
print(b)
# Out:
# 17
# 1

# %%
c = df['BloodPressure'].value_counts().max()
d = df['BloodPressure'].value_counts().min()
print(c)
print(d)
# Out:
# 57
# 1

# %%
e = df['SkinThickness'].value_counts().max()
f = df['SkinThickness'].value_counts().min()
print(e, f)
# Out:
# 227 1

# %%
g = df['Insulin'].value_counts().max()
h = df['Insulin'].value_counts().min()
print(g, h)
# Out:
# 374 1

# %%
i = df['BMI'].value_counts().max()
j = df['BMI'].value_counts().min()
print(i, j)
# Out:
# 13 1

# %%
k = df['DiabetesPedigreeFunction'].value_counts().max()
l = df['DiabetesPedigreeFunction'].value_counts().min()
print(k, l)
# Out:
# 6 1

# %%
m = df['Age'].value_counts().max()
n = df['Age'].value_counts().min()
print(m, n)
# Out:
# 72 1

# %% [markdown]
# ###  visualization time

# %%
plt.figure(figsize = (35, 20), dpi = 90)
ax = sns.countplot(x = 'Glucose', data = df)
plt.xticks(rotation = 90, fontsize= 20)
plt.yticks(fontsize = 20)
plt.xlabel('Glucose', fontsize = 20)
plt.ylabel('Count' , fontsize = 20)
plt.title('Count of Glucose', fontsize = 35)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (28, 8))
ax = sns.countplot(x = 'BloodPressure', data = df)
plt.xticks(rotation = 90, fontsize= 20)
plt.yticks(fontsize = 20)
plt.xlabel('BloodPressure', fontsize = 20)
plt.ylabel('Count' , fontsize = 20)
plt.title('Count of BloodPressure', fontsize = 35)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (28, 8))
ax = sns.countplot(x = 'SkinThickness', data = df)
plt.xticks(rotation = 90, fontsize= 20)
plt.yticks(fontsize = 20)
plt.xlabel('SkinThickness', fontsize = 20)
plt.ylabel('Count' , fontsize = 20)
plt.title('Count of SkinThickness', fontsize = 35)
plt.grid()
plt.show()

# %%
plt.figure(figsize = (35, 20), dpi = 90)
ax = sns.countplot(x = 'Age', data = df)
plt.xticks(rotation = 90, fontsize= 20)
plt.yticks(fontsize = 20)
plt.xlabel('Age', fontsize = 20)
plt.ylabel('Count' , fontsize = 20)
plt.title('Count of Age', fontsize = 35)
plt.grid()
plt.show()

# %%
Df = df[df['SkinThickness'] > 0]
DF = Df[df['SkinThickness'] < 90]
# Out:
# <ipython-input-24-79efab5f3ecf>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   DF = Df[df['SkinThickness'] < 90]

# %%
DF
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 3         89             66             23       94  28.1
# 4        137             40             35      168  43.1
# 6         78             50             32       88  31.0
# ..       ...            ...            ...      ...   ...
# 761      170             74             31        0  44.0
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 3                       0.167   21        0
# 4                       2.288   33        1
# ...

# %%
df2 = DF.copy()
df2
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 3         89             66             23       94  28.1
# 4        137             40             35      168  43.1
# 6         78             50             32       88  31.0
# ..       ...            ...            ...      ...   ...
# 761      170             74             31        0  44.0
# 763      101             76             48      180  32.9
# 764      122             70             27        0  36.8
# 765      121             72             23      112  26.2
# 767       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 3                       0.167   21        0
# 4                       2.288   33        1
# ...

# %%
df2.reset_index(drop = True, inplace = True)

# %%
df2
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2         89             66             23       94  28.1
# 3        137             40             35      168  43.1
# 4         78             50             32       88  31.0
# ..       ...            ...            ...      ...   ...
# 535      170             74             31        0  44.0
# 536      101             76             48      180  32.9
# 537      122             70             27        0  36.8
# 538      121             72             23      112  26.2
# 539       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.167   21        0
# 3                       2.288   33        1
# ...

# %% [markdown]
# ## time to train and test data

# %%
x = df2.drop('Outcome', axis = 1)
y = df2.Outcome.values.reshape(-1 ,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.35, random_state = 0)

# %%
clf = GaussianNB()
clf.fit(x_train ,y_train.ravel())
y_pred = clf.predict(x_test)

# %%
print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.7671957671957672

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
confusion_matrix(y, clf.predict(x))
# Out:
# array([[301,  60],
#        [ 65, 114]], dtype=int64)

# %%
plt.figure(figsize = (12, 8))
cm = confusion_matrix(y, clf.predict(x))
sns.heatmap(cm, annot = True, cbar = True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y, clf.predict(x)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83       361
#            1       0.66      0.64      0.65       179
#
#     accuracy                           0.77       540
#    macro avg       0.74      0.74      0.74       540
# weighted avg       0.77      0.77      0.77       540

# %% [markdown]
# ### the accuacy of this model with Gaussian nb is less than we expect then we need to work on it

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
kfold = KFold(5)
print(cross_val_score(clf, x, y.ravel(), cv = kfold, n_jobs = 1))
# Out:
# [0.7962963  0.66666667 0.75       0.78703704 0.77777778]

# %%
df3 = df2[df2.index < 108]
df4 = df2[df2.index > 216]
df5 = df3.append(df4)
df5.reset_index(drop = True, inplace = True)
df5
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2         89             66             23       94  28.1
# 3        137             40             35      168  43.1
# 4         78             50             32       88  31.0
# ..       ...            ...            ...      ...   ...
# 426      170             74             31        0  44.0
# 427      101             76             48      180  32.9
# 428      122             70             27        0  36.8
# 429      121             72             23      112  26.2
# 430       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.167   21        0
# 3                       2.288   33        1
# ...

# %%
x = df5.drop('Outcome', axis = 1)
y = df5.Outcome.values.reshape(-1, 1)
x
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2         89             66             23       94  28.1
# 3        137             40             35      168  43.1
# 4         78             50             32       88  31.0
# ..       ...            ...            ...      ...   ...
# 426      170             74             31        0  44.0
# 427      101             76             48      180  32.9
# 428      122             70             27        0  36.8
# 429      121             72             23      112  26.2
# 430       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.167   21
# 3                       2.288   33
# 4                       0.248   26
# ..                        ...  ...
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.35, random_state = 0)

# %%
clf2 = GaussianNB()
clf2.fit(x_train ,y_train.ravel())
y_pred = clf2.predict(x_test)

# %%
print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.8410596026490066

# %%
confusion_matrix(y, clf2.predict(x))
# Out:
# array([[255,  41],
#        [ 46,  89]], dtype=int64)

# %%
print(classification_report(y, clf2.predict(x)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85       296
#            1       0.68      0.66      0.67       135
#
#     accuracy                           0.80       431
#    macro avg       0.77      0.76      0.76       431
# weighted avg       0.80      0.80      0.80       431

# %%
plt.figure(figsize = (12, 8))
cm = confusion_matrix(y, clf2.predict(x))
sns.heatmap(cm, annot = True, cbar = True)
# Out:
# <AxesSubplot:>

# %%
df5
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2         89             66             23       94  28.1
# 3        137             40             35      168  43.1
# 4         78             50             32       88  31.0
# ..       ...            ...            ...      ...   ...
# 426      170             74             31        0  44.0
# 427      101             76             48      180  32.9
# 428      122             70             27        0  36.8
# 429      121             72             23      112  26.2
# 430       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.167   21        0
# 3                       2.288   33        1
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
x = df5.drop('Outcome', axis = 1).values
y = df5.Outcome.values.reshape(-1 ,1)

# %%
x
# Out:
# array([[148.   ,  72.   ,  35.   , ...,  33.6  ,   0.627,  50.   ],
#        [ 85.   ,  66.   ,  29.   , ...,  26.6  ,   0.351,  31.   ],
#        [ 89.   ,  66.   ,  23.   , ...,  28.1  ,   0.167,  21.   ],
#        ...,
#        [122.   ,  70.   ,  27.   , ...,  36.8  ,   0.34 ,  27.   ],
#        [121.   ,  72.   ,  23.   , ...,  26.2  ,   0.245,  30.   ],
#        [ 93.   ,  70.   ,  31.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
x_train,x_test, y_train, y_test = train_test_split(x, y, test_size = 0.35, random_state = 0)

# %%
k = 5
clf3 = KNeighborsClassifier(5)
clf3.fit(x_train, y_train.ravel())
y_pred = clf3.predict(x_test)

# %%
print("Accuracy: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.7682119205298014

# %% [markdown]
# ### to understand the best value of k we need to right a loop

# %%
k = 20
ACC = np.zeros((k))

for i in range(1, k+1 ):
    clf3 = KNeighborsClassifier(n_neighbors = i)
    clf3.fit(x_train, y_train.ravel())
    y_pred = clf3.predict(x_test)
    ACC[i -1] = metrics.accuracy_score(y_test, y_pred)
ACC
# Out:
# array([0.74172185, 0.76821192, 0.77483444, 0.77483444, 0.76821192,
#        0.7615894 , 0.78807947, 0.8013245 , 0.8013245 , 0.78807947,
#        0.78145695, 0.74172185, 0.74834437, 0.72847682, 0.74172185,
#        0.74172185, 0.76821192, 0.75496689, 0.75496689, 0.75496689])

# %%
print(np.max(ACC))
print(np.min(ACC))
# Out:
# 0.8013245033112583
# 0.7284768211920529

# %%
training_acc = []
testing_acc = []

neighbors_setting  = range(1 ,50)

for n_neighbors in neighbors_setting:
    knn = KNeighborsClassifier(n_neighbors = n_neighbors)
    knn.fit(x_train, y_train.ravel())
    training_acc.append(knn.score(x_train, y_train))
    testing_acc.append(knn.score(x_test, y_test))
    
plt.plot(neighbors_setting, training_acc, label = 'Accuracy of the training_acc')
plt.plot(neighbors_setting, testing_acc, label = 'Accuracy of the testing_acc')
plt.xlabel('number of neighbors')
plt.ylabel('Accuracy')
plt.grid()
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %% [markdown]
# ### improve model with Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {'n_neighbors': range(1, 50)}
grid_knn = GridSearchCV(estimator = knn,
                       param_grid = parameters,
                       scoring = 'accuracy',
                       cv = 5,
                       verbose = 1,
                       n_jobs = -1)
grid_knn.fit(x_train, y_train.ravel())
# Out:
# Fitting 5 folds for each of 49 candidates, totalling 245 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 245 out of 245 | elapsed:    4.6s finished
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(n_neighbors=49), n_jobs=-1,
#              param_grid={'n_neighbors': range(1, 50)}, scoring='accuracy',
#              verbose=1)

# %%
grid_knn.best_params_
# Out:
# {'n_neighbors': 3}

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
df5
# Out:
#      Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0        148             72             35        0  33.6
# 1         85             66             29        0  26.6
# 2         89             66             23       94  28.1
# 3        137             40             35      168  43.1
# 4         78             50             32       88  31.0
# ..       ...            ...            ...      ...   ...
# 426      170             74             31        0  44.0
# 427      101             76             48      180  32.9
# 428      122             70             27        0  36.8
# 429      121             72             23      112  26.2
# 430       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.167   21        0
# 3                       2.288   33        1
# ...

# %%
x = df5.drop('Outcome', axis = 1)
y = df5.Outcome.values.reshape(-1 ,1)

# %%
x_train,x_test, y_train, y_test = train_test_split(x, y, test_size = 0.35, random_state = 1)

# %%
clf = DecisionTreeClassifier(max_depth = 3)
clf.fit(x_train ,y_train.ravel())
y_pred = clf.predict(x_test)

# %%
print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.7086092715231788

# %%
from sklearn import tree

# %%
text_representation = tree.export_text(clf)
print(text_representation)
# Out:
# |--- feature_0 <= 124.50
# |   |--- feature_6 <= 30.50
# |   |   |--- feature_1 <= 79.00
# |   |   |   |--- class: 0
# |   |   |--- feature_1 >  79.00
# |   |   |   |--- class: 0
# |   |--- feature_6 >  30.50
# |   |   |--- feature_4 <= 32.15
# |   |   |   |--- class: 0
# |   |   |--- feature_4 >  32.15
# |   |   |   |--- class: 1
# |--- feature_0 >  124.50
# |   |--- feature_0 <= 165.50
# |   |   |--- feature_4 <= 28.15
# |   |   |   |--- class: 0
# |   |   |--- feature_4 >  28.15
# |   |   |   |--- class: 1
# |   |--- feature_0 >  165.50
# |   |   |--- feature_1 <= 108.00
# |   |   |   |--- class: 1
# |   |   |--- feature_1 >  108.00
# |   |   |   |--- class: 0

# %%
with open('decision_tree.log', 'w') as fout:
    fout.write(text_representation)

# %%
df5.columns
# Out:
# Index(['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %% [markdown]
# # plot decision tree white box

# %%
feature_name = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI','DiabetesPedigreeFunction', 'Age']
target_name = ['0', '1']
fig = plt.figure(figsize = (25, 20))
plot = tree.plot_tree(clf,
                     feature_names = feature_name,
                     class_names = target_name,
                     filled = True)
fig.savefig('Tree.png')

# %%
clf = DecisionTreeClassifier(criterion = 'entropy', max_depth = 3)
clf.fit(x_train ,y_train.ravel())
y_pred = clf.predict(x_test)

# %%
print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.7483443708609272

# %%
feature_name = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI','DiabetesPedigreeFunction', 'Age']
target_name = ['0', '1']
fig = plt.figure(figsize = (25, 20))
plot = tree.plot_tree(clf,
                     feature_names = feature_name,
                     class_names = target_name,
                     filled = True)
fig.savefig('Tree2.png')

# %% [markdown]
# # time to use Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x = df5.drop('Outcome', axis = 1)
y = df5.Outcome.values.reshape(-1 ,1)

# %%
x_train ,x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 1)

# %%
clf5 = RandomForestClassifier(n_estimators = 1000, max_depth = 3)
clf5.fit(x_train, y_train.ravel())
y_pred = clf5.predict(x_test)

# %%
print('Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy:  0.8307692307692308

# %%
feature_name = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI','DiabetesPedigreeFunction', 'Age']
target_name = ['0', '1']
fig = plt.figure(figsize = (25, 20))
plot = tree.plot_tree(clf5.estimators_[5],feature_names = feature_name , filled = True)

# %% [markdown]
# # work on this model with SVM

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC()
svm_model.fit(x_train, y_train.ravel())
y_pred = svm_model.predict(x_test)

# %%
print('Accuracy:', metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8076923076923077

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[84  7]
#  [18 21]]

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot = True, cbar = True)
# Out:
# <AxesSubplot:>
