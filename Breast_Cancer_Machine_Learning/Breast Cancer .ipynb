# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:\\Users\\10\\Downloads\\Compressed\\Breast_cancer.csv')
data
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate  Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated      3  Regional           4        Positive
# 1     Moderately differentiated      2  Regional          35        Positive
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage',
#        'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status'],
#       dtype='object')

# %%
data.describe()
# Out:
#                Age        Grade   Tumor Size  Regional Node Examined  \
# count  4024.000000  4024.000000  4024.000000             4024.000000
# mean     53.972167     2.150596    30.473658               14.357107
# std       8.963134     0.638234    21.119696                8.099675
# min      30.000000     1.000000     1.000000                1.000000
# 25%      47.000000     2.000000    16.000000                9.000000
# 50%      54.000000     2.000000    25.000000               14.000000
# 75%      61.000000     3.000000    38.000000               19.000000
# max      69.000000     4.000000   140.000000               61.000000
#
#        Reginol Node Positive  Survival Months
# count            4024.000000      4024.000000
# mean                4.158052        71.297962
# std                 5.109331        22.921430
# min                 1.000000         1.000000
# 25%                 1.000000        56.000000
# 50%                 2.000000        73.000000
# ...

# %%
print(f'checking for missing value:\n{data.isnull().sum()}')
# Out:
# checking for missing value:
# Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %%
data.columns
print(f'We need to change the columns name:\n {data.columns}')
# Out:
# We need to change the columns name:
#  Index(['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage',
#        'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status'],
#       dtype='object')

# %%
columns = ['Age', 'Race', 'Marital_Status', 'T_Stage', 'N_Stage', '6th_Stage',
       'differentiate', 'Grade', 'A_Stage', 'Tumor_Size', 'Estrogen_Status',
       'Progesterone_Status', 'Regional_Node_Examined',
       'Reginol_Node_Positive', 'Survival_Months', 'Status']

# %%
data.columns= columns

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     4024 non-null   int64
#  1   Race                    4024 non-null   object
#  2   Marital_Status          4024 non-null   object
#  3   T_Stage                 4024 non-null   object
#  4   N_Stage                 4024 non-null   object
#  5   6th_Stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   Grade                   4024 non-null   int64
#  8   A_Stage                 4024 non-null   object
#  9   Tumor_Size              4024 non-null   int64
#  10  Estrogen_Status         4024 non-null   object
#  11  Progesterone_Status     4024 non-null   object
#  12  Regional_Node_Examined  4024 non-null   int64
#  13  Reginol_Node_Positive   4024 non-null   int64
# ...

# %% [markdown]
# # Visualization

# %%
sns.set_style('darkgrid')

# %%
sns.pairplot(data)

# %%
plt.figure(figsize = (15, 10))
sns.countplot(x = data['Age'], data = data)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
Categorical = ['Race', 'Marital_Status', 'T_Stage', 'N_Stage', '6th_Stage', 'differentiate', 'A_Stage'
               , 'Estrogen_Status', 'Progesterone_Status', 'Status']
i = 0
while i < 10:
    plt.figure(figsize = (20, 4))
    plt.subplot(1, 3, 1)
    sns.countplot(x = Categorical[i], data = data)
    plt.xticks(rotation = 45)
    i += 1
    if i == 10:
        break
    
    plt.subplot(1, 3, 2)
    sns.countplot(x = Categorical[i], data = data)
    plt.xticks(rotation = 45)
    i += 1
    
    plt.subplot(1, 3, 3)
    sns.countplot(x = Categorical[i], data = data)
    plt.xticks(rotation = 45)
    i += 1

# %%
Numerical = ['Age', 'Grade', 'Tumor_Size', 'Regional_Node_Examined', 'Reginol_Node_Positive', 'Survival_Months']
i = 0
while i < 6:
    plt.figure(figsize = (20, 4))
    plt.subplot(1, 2, 1)
    sns.boxplot(x = Numerical[i], data =data)
    plt.xticks(rotation = 45)
    i += 1
    if i == 5:
        break
    plt.subplot(1, 2, 2)
    sns.boxplot(x = Numerical[i], data =data)
    plt.xticks(rotation = 45)
    i += 1

# %%
Categorical = ['Marital_Status', 'T_Stage', 'N_Stage', '6th_Stage', 'differentiate', 'A_Stage'
               , 'Estrogen_Status', 'Progesterone_Status', 'Status']
Numerical = ['Age', 'Grade', 'Tumor_Size', 'Regional_Node_Examined', 'Reginol_Node_Positive', 'Survival_Months']

# %%
for i in Categorical:
    a = data[i].unique()
    print(i, a)
# Out:
# Marital_Status ['Married' 'Divorced' 'Single ' 'Widowed' 'Separated']
# T_Stage ['T1' 'T2' 'T3' 'T4']
# N_Stage ['N1' 'N2' 'N3']
# 6th_Stage ['IIA' 'IIIA' 'IIIC' 'IIB' 'IIIB']
# differentiate ['Poorly differentiated' 'Moderately differentiated' 'Well differentiated'
#  'Undifferentiated']
# A_Stage ['Regional' 'Distant']
# Estrogen_Status ['Positive' 'Negative']
# Progesterone_Status ['Positive' 'Negative']
# Status ['Alive' 'Dead']

# %% [markdown]
# # Prepare for Machine learning

# %%
data['Marital_Status'].replace({'Married':2, 'Divorced':3, 'Single ':4, 'Widowed':5, 'Separated':6}, inplace = True )
data['T_Stage'].replace({'T1':2, 'T2':3, 'T3':4, 'T4':5}, inplace = True)
data['N_Stage'].replace({'N1':2, 'N2':3, 'N3':4},inplace = True )
data['6th_Stage'].replace({'IIA':2, 'IIIA':3, 'IIIC':4, 'IIB':5, 'IIIB':6}, inplace = True)
data['differentiate'].replace({'Poorly differentiated':2, 'Moderately differentiated':3, 'Well differentiated':4, 'Undifferentiated':5}, inplace = True)
data['A_Stage'].replace({'Regional':2, 'Distant':3}, inplace = True)
data['Estrogen_Status'].replace({'Positive':2, 'Negative':3}, inplace = True)
data['Progesterone_Status'].replace({'Positive':2, 'Negative':3}, inplace = True)
data['Status'].replace({'Alive':1, 'Dead':0}, inplace = True)

# %%
data
# Out:
#       Age   Race  Marital_Status  T_Stage  N_Stage  6th_Stage  differentiate  \
# 0      68  White               2        2        2          2              2
# 1      50  White               2        3        3          3              3
# 2      58  White               3        4        4          4              3
# 3      58  White               2        2        2          2              2
# 4      47  White               2        3        2          5              2
# ...   ...    ...             ...      ...      ...        ...            ...
# 4019   62  Other               2        2        2          2              3
# 4020   56  White               3        3        3          3              3
# 4021   68  White               2        3        2          5              3
# 4022   58  Black               3        3        2          5              3
# 4023   46  White               2        3        2          5              3
#
# ...

# %%
data['Race'].unique()
# Out:
# array(['White', 'Black', 'Other'], dtype=object)

# %%
data['Race'].replace({'White':2, 'Black':3, 'Other': 4}, inplace = True)

# %%
data
# Out:
#       Age  Race  Marital_Status  T_Stage  N_Stage  6th_Stage  differentiate  \
# 0      68     2               2        2        2          2              2
# 1      50     2               2        3        3          3              3
# 2      58     2               3        4        4          4              3
# 3      58     2               2        2        2          2              2
# 4      47     2               2        3        2          5              2
# ...   ...   ...             ...      ...      ...        ...            ...
# 4019   62     4               2        2        2          2              3
# 4020   56     2               3        3        3          3              3
# 4021   68     2               2        3        2          5              3
# 4022   58     3               3        3        2          5              3
# 4023   46     2               2        3        2          5              3
#
# ...

# %%
data.isnull().sum()
# Out:
# Age                       0
# Race                      0
# Marital_Status            0
# T_Stage                   0
# N_Stage                   0
# 6th_Stage                 0
# differentiate             0
# Grade                     0
# A_Stage                   0
# Tumor_Size                0
# Estrogen_Status           0
# Progesterone_Status       0
# Regional_Node_Examined    0
# Reginol_Node_Positive     0
# Survival_Months           0
# Status                    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report

# %%
x = data.drop('Status', axis = 1)
y = data.Status.values.reshape(-1, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.15, random_state = 0)

# %%
model = LogisticRegression(solver = 'liblinear')
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
# Out:
# C:\Users\10\anaconda2\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print('Logistic Regression Accuracy', metrics.accuracy_score(y_test, y_pred))
# Out:
# Logistic Regression Accuracy 0.9089403973509934

# %%
confusion_matrix(y, clf.predict(x))
# Out:
# array([[ 290,  326],
#        [ 394, 3014]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.44      0.57        89
#            1       0.91      0.98      0.94       515
#
#     accuracy                           0.90       604
#    macro avg       0.85      0.71      0.75       604
# weighted avg       0.89      0.90      0.89       604

# %% [markdown]
# # Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB

# %%
clf = GaussianNB()
clf.fit(x_train, y_train.ravel())
y_pred = clf.predict(x_test)

# %%
print('Gaussian NB Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Gaussian NB Accuracy:  0.9089403973509934

# %%
confusion_matrix(y, clf.predict(x))
# Out:
# array([[ 290,  326],
#        [ 394, 3014]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.48      0.45        89
#            1       0.91      0.88      0.90       515
#
#     accuracy                           0.82       604
#    macro avg       0.66      0.68      0.67       604
# weighted avg       0.84      0.82      0.83       604

# %%
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # knn

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
k = 50
Acc = np.zeros((k))

for i in range(1, k+1):
    clf2 = KNeighborsClassifier(n_neighbors= i)
    clf2.fit(x_train, y_train.ravel())
    y_pred = clf2.predict(x_test)
    Acc[i-1] = metrics.accuracy_score(y_test, y_pred)

Acc
# Out:
# array([0.84271523, 0.79635762, 0.88907285, 0.87582781, 0.89403974,
#        0.89900662, 0.89735099, 0.89900662, 0.90066225, 0.90066225,
#        0.90231788, 0.90231788, 0.90397351, 0.90231788, 0.90397351,
#        0.90562914, 0.90562914, 0.90728477, 0.90728477, 0.9089404 ,
#        0.90562914, 0.90562914, 0.90231788, 0.90562914, 0.90397351,
#        0.90728477, 0.90728477, 0.90397351, 0.90562914, 0.90562914,
#        0.90397351, 0.90562914, 0.90728477, 0.90397351, 0.90397351,
#        0.90397351, 0.90562914, 0.90562914, 0.90728477, 0.90562914,
#        0.90728477, 0.90728477, 0.90728477, 0.90562914, 0.90728477,
#        0.90397351, 0.90231788, 0.90231788, 0.90397351, 0.90562914])

# %%
print(Acc.min())
print(Acc.max())
# Out:
# 0.7963576158940397
# 0.9089403973509934

# %%
clf2 = KNeighborsClassifier(n_neighbors= 20)
clf2.fit(x_train, y_train.ravel())
y_pred = clf2.predict(x_test)
print(f'KNN Accuracy: {metrics.accuracy_score(y_test, y_pred)}')
# Out:
# KNN Accuracy: 0.9089403973509934

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier(max_depth= 3)
dtc.fit(x_train, y_train)
y_pred = dtc.predict(x_test)

# %%
print('Decision Tree Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Decision Tree Accuracy:  0.8956953642384106

# %% [markdown]
# # Randon Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf3 = RandomForestClassifier(n_estimators = 1000, max_depth= 3)
clf3.fit(x_train, y_train)
y_pred = clf3.predict(x_test)

# %%
print('Random Forest Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# Random Forest Accuracy:  0.8956953642384106

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
clf4 = SVC(kernel = 'linear')
clf4.fit(x_train, y_train)
y_pred = clf4.predict(x_test)
print('SVM Accuracy: ', metrics.accuracy_score(y_test, y_pred))
# Out:
# SVM Accuracy:  0.8956953642384106

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
sns.heatmap(cm, annot = True)
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.48      0.61        89
#            1       0.92      0.98      0.95       515
#
#     accuracy                           0.91       604
#    macro avg       0.87      0.73      0.78       604
# weighted avg       0.90      0.91      0.90       604
